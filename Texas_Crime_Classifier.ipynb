# %%
import pandas as pd
import re
import numpy as np

# %%
ls
# Out:
# NAME.txt
# NAME.xml
# OND_eligibility_labeled_data_texas_v3.csv
# OND_eligibility_labeled_data_texas_vnew.csv
# Photo.txt
# Photo.xml
# TX-DPS-DATA-210419_0711/
# common_charges_across_texas_state_sample.csv
# common_charges_first_time_misd_conv_final.csv
# common_charges_misd_conv_final.csv
# misd_charge_list_with_count.csv
# misd_charge_list_with_count_v2.csv
# mris_eligibility_labeled_data_texas_vnew.csv
# offensecodes.xls
# offensecodes_p2.xlsx
# offensecodes_p3.xlsx
# tx_check/
# tx_misd_after_elig_label.csv
# tx_misd_after_elig_label_v2.csv
# tx_misd_after_elig_label_v3.csv
# vc1.csv
# vc2.csv

# %%
tx = pd.read_excel('')

# %%
df = pd.read_csv("OND_eligibility_labeled_data_texas_v3.csv")
df.head(10)
# Out:
#    Unnamed: 0  Unnamed: 0.1      Id         DOB  Age Date_Of_Offense  \
# 0           0             0  940134  1948-02-12   73      1974-07-11
# 1           1             1  940134  1948-02-12   73      1974-07-11
# 2           2             2  940134  1948-02-12   73      2010-08-04
# 3           3             3  940134  1948-02-12   73      2008-08-23
# 4           4             4  940134  1948-02-12   73      1974-07-11
# 5           5             5  940134  1948-02-12   73      1974-07-11
# 6           6             6  940134  1948-02-12   73      2010-08-04
# 7           7             7  940134  1948-02-12   73      2008-08-23
# 8           8             8  942246  1947-06-20   74      1968-08-16
# 9           9             9  942246  1947-06-20   74      1968-08-16
#
#   Sentence_Start_Date Disposition_Date Sentence_Expiration_Date  \
# 0          07/11/1974       06/14/2013                      NaN
# 1          06/17/1977       06/14/2013                      NaN
# ...

# %%
df.rename(columns={"Charge_Raw": 'Offense'}, inplace=True)

# %%
df['Offense'] = df['Offense'].str.lower()
df['Offense'] = df['Offense'].str.replace(' w/prev.*', '', regex=True)
df['Crime_Classification'] = ''
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1      Id         DOB  Age Date_Of_Offense  \
# 0           0             0  940134  1948-02-12   73      1974-07-11
# 1           1             1  940134  1948-02-12   73      1974-07-11
# 2           2             2  940134  1948-02-12   73      2010-08-04
# 3           3             3  940134  1948-02-12   73      2008-08-23
# 4           4             4  940134  1948-02-12   73      1974-07-11
#
#   Sentence_Start_Date Disposition_Date Sentence_Expiration_Date  \
# 0          07/11/1974       06/14/2013                      NaN
# 1          06/17/1977       06/14/2013                      NaN
# 2          08/04/2010       06/14/2013               2010-11-29
# 3          11/29/2010       06/14/2013               2010-11-29
# 4          07/11/1974       07/09/2010                      NaN
#
#   Parole_Until_Date  ... Domestic_Violence CSC_COD_probation_status  \
# 0               NaN  ...                 N                        a
# ...

# %% [markdown]
# # Checking occurences of crimes using keywords in Texas

# %% [markdown]
# #### Checking for property crimes

# %%
print(list(df[df['Offense'].str.contains('burglary', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('arson', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('auto theft', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('fraud', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('forgery', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('grand theft', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('petty theft', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('theft', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('financial', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('finance', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('stolen', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('destruct', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('destruction', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('property', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('trespass', na=False)].Offense.unique()))
print()
# Out:
# ['burglary of habitation', 'burglary of building', 'burglary of coin operated/collection machine', 'burglary habitation intend other felony', 'burglary of vehicles', 'burglary of vehicle w/2+ conv iat', 'burglary habitation intend sex offense', 'burglary of building cntrlld substance present']
#
# ['arson intend damage hab/place of worship iat', 'arson causing bodily injury/death iat', 'arson reck damage bldg/reck cause bi or death', 'arson', 'arson w/man/att man cont sub dmge bldg/hab/veh']
#
# []
#
# ...

# %% [markdown]
# #### Adding property crimes classifications to dataframe

# %%
df['Crime_Classification'] = np.where(df['Offense'].str.contains('burglary'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(((df['Offense'].str.contains('arson')) & ('inj' not in df['Offense']) & 
                                   ('death' not in df['Offense'])), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('auto theft'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('fraud'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('forgery'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('grand theft'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('petty theft'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('theft'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('financial'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('stolen'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('destruct'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('destruction'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('property'), 'property crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('trespass'), 'property crimes', df.Crime_Classification)
df
# Out:
#          Unnamed: 0  Unnamed: 0.1       Id         DOB  Age Date_Of_Offense  \
# 0                 0             0   940134  1948-02-12   73      1974-07-11
# 1                 1             1   940134  1948-02-12   73      1974-07-11
# 2                 2             2   940134  1948-02-12   73      2010-08-04
# 3                 3             3   940134  1948-02-12   73      2008-08-23
# 4                 4             4   940134  1948-02-12   73      1974-07-11
# ...             ...           ...      ...         ...  ...             ...
# 2603705     2603705       2603705  6794344  1981-01-06   40      2002-05-07
# 2603706     2603706       2603706  6794344  1981-01-06   40      2009-05-05
# 2603707     2603707       2603707  6794344  1981-01-06   40      2002-05-07
# 2603708     2603708       2603708  6794344  1981-01-06   40      2002-05-07
# 2603709     2603709       2603709  6794344  1981-01-06   40      2002-05-07
#
# ...

# %% [markdown]
# #### Checking for drug crimes

# %%
print(list(df[df['Offense'].str.contains('heroin', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('amphetamines', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('cocaine', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('crack', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('opioids', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('drug', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('substance', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('substances', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('marij', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('marijuana', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('possession', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('poss', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('prescription', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('paraphernalia', na=False)].Offense.unique()))
# Out:
# []
#
# []
#
# []
#
# []
#
# []
#
# ['poss dangerous drug', 'false drug test falsification device', 'del offer  del of dangerous drug', 'poss del drug paraphernalia', 'false drug test man/del subst/device', 'man dangerous drug', 'forge/incr prescr quan/dangerous drug enh', 'oper drug treatment facility w/o license', 'dispense dangerous drug/controlled substance', 'forge/increase prescr quantity/danger drug']
#
# ['proh substance/item in corr/civ com facility', 'burglary of building cntrlld substance present', 'transfer precursor substance unl man', 'dispense dangerous drug/controlled substance']
#
# []
#
# ['poss marij <2oz', 'poss marij >2oz<=4oz', 'poss marij >50lbs<=2,000lbs', 'poss marij >4oz<=5lbs', 'poss marij >5lbs<=50lbs', 'del marij <= 1/4 oz remuneration', 'del marij >5lbs<=50lbs', 'del marij >1/4 oz<=5lbs', 'poss marij >2,000lbs', 'del marij <= 1/4 oz', 'del marij >50lbs<=2,000lbs', 'del cs/marij to minor']
#
# []
#
# []
#
# ...

# %% [markdown]
# #### Adding drug crimes classifications to dataframe

# %%
df['Crime_Classification'] = np.where(((df['Offense'].str.contains('drug')) & ('burglary' not in df['Offense']) & 
                                       ('theft' not in df['Offense'])), 'drug crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(((df['Offense'].str.contains('substance')) & ('burglary' not in df['Offense']) & 
                                       ('theft' not in df['Offense'])), 'drug crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('marij'), 'drug crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(((df['Offense'].str.contains('poss')) & (df['Offense'].str.contains('cs'))), 'drug crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('prescription'), 'drug crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('paraphernalia'), 'drug crimes', df.Crime_Classification)
df
# Out:
#          Unnamed: 0  Unnamed: 0.1       Id         DOB  Age Date_Of_Offense  \
# 0                 0             0   940134  1948-02-12   73      1974-07-11
# 1                 1             1   940134  1948-02-12   73      1974-07-11
# 2                 2             2   940134  1948-02-12   73      2010-08-04
# 3                 3             3   940134  1948-02-12   73      2008-08-23
# 4                 4             4   940134  1948-02-12   73      1974-07-11
# ...             ...           ...      ...         ...  ...             ...
# 2603705     2603705       2603705  6794344  1981-01-06   40      2002-05-07
# 2603706     2603706       2603706  6794344  1981-01-06   40      2009-05-05
# 2603707     2603707       2603707  6794344  1981-01-06   40      2002-05-07
# 2603708     2603708       2603708  6794344  1981-01-06   40      2002-05-07
# 2603709     2603709       2603709  6794344  1981-01-06   40      2002-05-07
#
# ...

# %% [markdown]
# #### Checking for DUI crimes

# %%
print(list(df[df['Offense'].str.contains('driving', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('dui', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('drive', na=False)].Offense.unique()))
# Out:
# ['driving while intoxicated', 'driving while intoxicated 3rd or more iat', 'driving while intoxicated 2nd', 'driving while intoxicated w/child under 15 yoa', 'driving while intoxicated bac >= 0.15', 'driving w/lic inv', 'driving while intoxicated/open alch container', 'driving under influence minor 3rd-enh', 'reckless driving', 'driving w/viol fin resp accident sbi/death']
#
# []
#
# ['driver license/id false', 'viol of occupational drivers license', 'false application on drivers license', 'surrender of drivers license']

# %%
df['Crime_Classification'] = np.where(df['Offense'].str.contains('driving'), 'dui crimes', df.Crime_Classification)
df
# Out:
#          Unnamed: 0  Unnamed: 0.1       Id         DOB  Age Date_Of_Offense  \
# 0                 0             0   940134  1948-02-12   73      1974-07-11
# 1                 1             1   940134  1948-02-12   73      1974-07-11
# 2                 2             2   940134  1948-02-12   73      2010-08-04
# 3                 3             3   940134  1948-02-12   73      2008-08-23
# 4                 4             4   940134  1948-02-12   73      1974-07-11
# ...             ...           ...      ...         ...  ...             ...
# 2603705     2603705       2603705  6794344  1981-01-06   40      2002-05-07
# 2603706     2603706       2603706  6794344  1981-01-06   40      2009-05-05
# 2603707     2603707       2603707  6794344  1981-01-06   40      2002-05-07
# 2603708     2603708       2603708  6794344  1981-01-06   40      2002-05-07
# 2603709     2603709       2603709  6794344  1981-01-06   40      2002-05-07
#
# ...

# %% [markdown]
# #### Checking for public order crimes

# %%
print(list(df[df['Offense'].str.contains('riot', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('custody', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('pros', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('prosecution', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('weapons', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('habitual offender', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('parole', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('probation', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('contempt', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('court order', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('morals', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('decency', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('immigration', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('obstruction', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('resisting', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('resist', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('privacy', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('invasion', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('commercialized', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('commercialize', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('deliquency', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('disorderly', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('disorder', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('liqour', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('law violation', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('tax', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('taxation', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('bribe', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('bribery', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('conflict of interest', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('public order', na=False)].Offense.unique()))
# Out:
# ['riot participation']
#
# ['escape from custody', 'unl restraint while in custody', 'civil rights person in custody violate/sexual', 'implements for escape corr facility/custody']
#
# ['prostitution w/3rd or more', 'prostitution', 'hinder apprehension/prosecution', 'hinder apprehension or prosecution known felon', 'prostitution with one/two prev convic', 'hindering appreh/pros known felon sex offender', 'prostitution/other payor', 'compel prost by force/threat/coercion/fraud']
#
# ['hinder apprehension/prosecution', 'hinder apprehension or prosecution known felon']
#
# []
#
# []
#
# []
#
# []
#
# ['contempt of court refuses to testify', 'contempt of court disobedience of court order']
#
# ['viol court order enj organized crime act', 'contempt of court disobedience of court order', 'unl poss firearm family/household/court order']
#
# []
#
# ['indecency w/child sexual contact', 'indecency w/a child exposes']
#
# []
#
# ['obstruction or retaliation']
#
# []
#
# ...

# %% [markdown]
# #### Adding public order crimes classifications

# %%
df['Crime_Classification'] = np.where(df['Offense'].str.contains('riot'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(((df['Offense'].str.contains('custody')) & ('burglary' not in df['Offense'])), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('prostitution'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('prosecution'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('weapons'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('contempt'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('court order'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('morals'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('immigration'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('obstruction'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('resist'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('privacy'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('disorderly'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('tax'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('bribery'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('conflict of interest'), 'public order crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('public order'), 'public order crimes', df.Crime_Classification)
df
# Out:
#          Unnamed: 0  Unnamed: 0.1       Id         DOB  Age Date_Of_Offense  \
# 0                 0             0   940134  1948-02-12   73      1974-07-11
# 1                 1             1   940134  1948-02-12   73      1974-07-11
# 2                 2             2   940134  1948-02-12   73      2010-08-04
# 3                 3             3   940134  1948-02-12   73      2008-08-23
# 4                 4             4   940134  1948-02-12   73      1974-07-11
# ...             ...           ...      ...         ...  ...             ...
# 2603705     2603705       2603705  6794344  1981-01-06   40      2002-05-07
# 2603706     2603706       2603706  6794344  1981-01-06   40      2009-05-05
# 2603707     2603707       2603707  6794344  1981-01-06   40      2002-05-07
# 2603708     2603708       2603708  6794344  1981-01-06   40      2002-05-07
# 2603709     2603709       2603709  6794344  1981-01-06   40      2002-05-07
#
# ...

# %% [markdown]
# #### Checking for traffic crimes

# %%
print(list(df[df['Offense'].str.contains('traffic', na=False)].Offense.unique()))
# Out:
# ['traffic offense class c']

# %%
df['Crime_Classification'] = np.where(df['Offense'].str.contains('traffic offense'), 'traffic crimes', df.Crime_Classification)
df
# Out:
#          Unnamed: 0  Unnamed: 0.1       Id         DOB  Age Date_Of_Offense  \
# 0                 0             0   940134  1948-02-12   73      1974-07-11
# 1                 1             1   940134  1948-02-12   73      1974-07-11
# 2                 2             2   940134  1948-02-12   73      2010-08-04
# 3                 3             3   940134  1948-02-12   73      2008-08-23
# 4                 4             4   940134  1948-02-12   73      1974-07-11
# ...             ...           ...      ...         ...  ...             ...
# 2603705     2603705       2603705  6794344  1981-01-06   40      2002-05-07
# 2603706     2603706       2603706  6794344  1981-01-06   40      2009-05-05
# 2603707     2603707       2603707  6794344  1981-01-06   40      2002-05-07
# 2603708     2603708       2603708  6794344  1981-01-06   40      2002-05-07
# 2603709     2603709       2603709  6794344  1981-01-06   40      2002-05-07
#
# ...

# %% [markdown]
# #### Checking for violent crimes

# %%
print(list(df[df['Offense'].str.contains('violent', na=False)].Offense.unique()))
print()
print(df[df['Offense'].str.contains('homicide', na=False)].Offense.unique())
print()
print(df[df['Offense'].str.contains('murder', na=False)].Offense.unique())
print()
print(list(df[df['Offense'].str.contains('mans', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('kidnap', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('rape', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('sexual', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('assualt', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('traffic', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('robbery', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('abuse', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('threat', na=False)].Offense.unique()))
print()
print(list(df[df['Offense'].str.contains('inj', na=False)].Offense.unique()))
print()
# Out:
# []
#
# ['criminal negligent homicide']
#
# ['capital murder of a peace officer or fireman'
#  'capital murder person while escaping/attempt' 'murder'
#  'capital murder of multiple persons' 'capital murder while remuneration'
#  'capital murder by terror threat/other felony'
#  'capital murder of person under ten yoa'
#  'murder under influence of sudden passion'
#  'capital murder of another person in prison']
#
# ['manslaughter', 'intoxication manslaughter w/vehicle']
#
# ['agg kidnapping terrorize', 'kidnapping', 'agg kidnapping facilitate', 'agg kidnapping for ransom/reward', 'agg kidnapping bi/sexual abuse', 'agg kidnapping bi/sexual abuse safe release', 'agg kidnapping interfere performance', 'agg kidnapping facilitate safe release', 'agg kidnapping use as shield/hostage']
#
# []
#
# ...

# %% [markdown]
# #### Adding violent crimes classifications to dataframe

# %%
df['Crime_Classification'] = np.where(df['Offense'].str.contains('violent'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('homicide'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('murder'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('mans'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('kidnap'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('rape'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('sexual'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('assault'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(((df['Offense'].str.contains('traffic')) & ('offense' not in df['Offense'])), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('robbery'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('sex abuse'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('sexual abuse'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('child abuse'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('threat'), 'violent crimes', df.Crime_Classification)
df['Crime_Classification'] = np.where(df['Offense'].str.contains('inj'), 'violent crimes', df.Crime_Classification)
df
# Out:
#          Unnamed: 0  Unnamed: 0.1       Id         DOB  Age Date_Of_Offense  \
# 0                 0             0   940134  1948-02-12   73      1974-07-11
# 1                 1             1   940134  1948-02-12   73      1974-07-11
# 2                 2             2   940134  1948-02-12   73      2010-08-04
# 3                 3             3   940134  1948-02-12   73      2008-08-23
# 4                 4             4   940134  1948-02-12   73      1974-07-11
# ...             ...           ...      ...         ...  ...             ...
# 2603705     2603705       2603705  6794344  1981-01-06   40      2002-05-07
# 2603706     2603706       2603706  6794344  1981-01-06   40      2009-05-05
# 2603707     2603707       2603707  6794344  1981-01-06   40      2002-05-07
# 2603708     2603708       2603708  6794344  1981-01-06   40      2002-05-07
# 2603709     2603709       2603709  6794344  1981-01-06   40      2002-05-07
#
# ...

# %% [markdown]
# #### Federal crimes

# %%
print(list(df[df['Offense'].str.contains('federal', na=False)].Offense.unique()))
print()
# Out:
# []

# %%
df['Crime_Classification'] = np.where(df['Offense'].str.contains('federal'), 'federal crimes', df.Crime_Classification)

# %% [markdown]
# ### Create CSV file from data

# %%
#df.to_csv('texas_crime_classification.csv')

# %%
df.Crime_Classification.value_counts()
# Out:
# drug crimes            858441
#                        509557
# violent crimes         399829
# dui crimes             385214
# property crimes        381028
# public order crimes     69641
# Name: Crime_Classification, dtype: int64

# %%
df[['Id', 'Offense', 'Crime_Classification']]
# Out:
#               Id                                     Offense  \
# 0         940134                            poss cs pg 1 <1g
# 1         940134                            poss cs pg 1 <1g
# 2         940134                            poss cs pg 1 <1g
# 3         940134                            poss cs pg 1 <1g
# 4         940134  fail to id fugitive intent give false info
# ...          ...                                         ...
# 2603705  6794344                   man del cs pg 1 >=4g<200g
# 2603706  6794344                   man del cs pg 1 >=4g<200g
# 2603707  6794344                   man del cs pg 1 >=4g<200g
# 2603708  6794344                   man del cs pg 1 >=4g<200g
# 2603709  6794344                   man del cs pg 1 >=4g<200g
#
#         Crime_Classification
# 0                drug crimes
# 1                drug crimes
# 2                drug crimes
# 3                drug crimes
# 4
# ...                      ...
# 2603705
# 2603706
# 2603707
# 2603708
# ...

# %%
df1 = df[['Id', 'Offense', 'Crime_Classification']].copy()

# %%
df1['Crime_Classification'].replace('', 'other', inplace=True)
df1
# Out:
#               Id                                     Offense  \
# 0         940134                            poss cs pg 1 <1g
# 1         940134                            poss cs pg 1 <1g
# 2         940134                            poss cs pg 1 <1g
# 3         940134                            poss cs pg 1 <1g
# 4         940134  fail to id fugitive intent give false info
# ...          ...                                         ...
# 2603705  6794344                   man del cs pg 1 >=4g<200g
# 2603706  6794344                   man del cs pg 1 >=4g<200g
# 2603707  6794344                   man del cs pg 1 >=4g<200g
# 2603708  6794344                   man del cs pg 1 >=4g<200g
# 2603709  6794344                   man del cs pg 1 >=4g<200g
#
#         Crime_Classification
# 0                drug crimes
# 1                drug crimes
# 2                drug crimes
# 3                drug crimes
# 4                      other
# ...                      ...
# ...

# %%
df1.Crime_Classification.value_counts()
# Out:
# drug crimes            858441
# other                  509557
# violent crimes         399829
# dui crimes             385214
# property crimes        381028
# public order crimes     69641
# Name: Crime_Classification, dtype: int64

# %%
343459/2603710
# Out:
# 0.13191138798099636

# %%
df1[df1['Crime_Classification']=='other'].Offense.value_counts().sum()
# Out:
# 343459

# %%
df1[df1['Crime_Classification']=='other'].Offense.value_counts()
# Out:
# unauth use of vehicle                             68306
# man del cs pg 1 <1g                               58457
# man del cs pg 1 >=4g<200g                         58385
# fail to id fugitive intent give false info        55272
# man del cs pg 1 >=1g<4g                           31863
#                                                   ...
# trademark counterfeiting >=$2,500<$30k                1
# drvng disq/comm w/prv cnv/susp/w/o fin res iat        1
# misapp fiduc/finan prop >=$150k<$300k                 1
# del alcohol away from lic permise                     1
# evading arrest det tire defla dev against off         1
# Name: Offense, Length: 344, dtype: int64

# %%
df1['Crime_Classification'] = np.where(df1['Offense'].str.contains('man del cs pg'), 'drug crimes', df1.Crime_Classification)

# %%
df1[df1['Crime_Classification']=='other'].Offense.value_counts().head(10)
# Out:
# unauth use of vehicle                             68306
# fail to id fugitive intent give false info        55272
# evading arrest detention                          27370
# evading arrest det w/veh                          23433
# credit card or debit card abuse                   21887
# public intoxication w/3 prior convictions         14177
# evading arrest det                                11196
# fail to comply sex off duty to reg life/annual     9220
# interfer w/emergency req for assistance            8763
# fail to id fugitive frm justice refuse to give     7120
# Name: Offense, dtype: int64

# %%
df1['Crime_Classification'] = np.where(df1['Offense'].str.contains('public intoxication w/3 prior convictions'), 'public order crimes', df1.Crime_Classification)

# %%
df1[df1['Crime_Classification']=='other'].Offense.value_counts().head(10).sum()
# Out:
# 96928

# %%
round((96928/2603710)*100, 2)
# Out:
# 3.72

# %%
df1['Crime_Classification'] = np.where(df1['Offense'].str.contains('bail jumping and fail to appear'), 'public order crimes', df1.Crime_Classification)

# %%
df1['Crime_Classification'] = np.where(df1['Offense'].str.contains('fail to comply sex off duty to reg life/annual'), 'public order crimes', df1.Crime_Classification)

# %%
df1['Crime_Classification'] = np.where(df1['Offense'].str.contains('unauth use of vehicle'), 'property crimes', df1.Crime_Classification)

# %%
df1['Crime_Classification'] = np.where(df1['Offense'].str.contains('credit card or debit card abuse'), 'property crimes', df1.Crime_Classification)

# %%
df1['Crime_Classification'] = np.where(df1['Offense'].str.contains('evading arrest'), 'public order crimes', df1.Crime_Classification)
